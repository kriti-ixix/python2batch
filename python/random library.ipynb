# %%
pip install random
# Out:
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random
# Note: you may need to restart the kernel to use updated packages.

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# Shift + Tab to see the documentation of any function

# %% [markdown]
# **Importing a library**

# %%
import random

# %% [markdown]
# Returns some integer value between a & b

# %%
random.randint(1, 10)
# Out:
# 2

# %%
random.getstate()
# Out:
# (3,
#  (1494474828,
#   3624385261,
#   3276746484,
#   2261741446,
#   460377738,
#   3910616838,
#   94655681,
#   2357427162,
#   150212977,
#   3675634300,
#   2005136609,
#   685176687,
#   638415815,
#   1066354871,
#   3234456726,
#   3322902589,
#   1334259905,
#   3946454749,
#   890027589,
#   3540331851,
#   2073246555,
#   604787941,
#   396304584,
#   663216323,
#   2424428602,
#   1026475419,
#   2451844808,
#   1139070840,
#   3523852468,
#   3308813465,
#   1321325548,
#   486456170,
#   3188270233,
#   3706357365,
#   470920204,
#   4164074997,
#   2380892993,
#   4036030135,
#   186091492,
#   1396742448,
#   2585428594,
#   891284593,
#   1512935425,
#   46430340,
#   140130405,
#   441977084,
#   3928840969,
#   4101296904,
#   2341707121,
#   1842065320,
#   1071541657,
#   3406578536,
#   2505348892,
#   561498482,
#   212604433,
#   2957555999,
#   4197492479,
#   2745236565,
#   247025914,
#   3734323490,
#   674467666,
#   4055982336,
#   4140211053,
# ...

# %% [markdown]
# Returns random float value between a & b

# %%
random.uniform(1, 10)
# Out:
# 7.544670133552885

# %% [markdown]
# Returns random value between 0 and 1

# %%
random.random()
# Out:
# 0.03627601770361699

# %% [markdown]
# **Importing using an alias**

# %%
import random as r

# %%
r.random()
# Out:
# 0.9793785531145545

# %%
myList = [1, 2, 3, "X", True, "Hi!"]
r.choice(myList)
# Out:
# True

# %% [markdown]
# **Importing just select functions**

# %%
from random import randint, uniform

# %%
randint(1, 100)
# Out:
# 5

# %%
uniform(1, 50)
# Out:
# 4.624857604885552

# %%
number = random.randint(0, 10)
