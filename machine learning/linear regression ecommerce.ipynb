# %% [markdown]
# **Import the libaries you'll need**

# %% [markdown]
# **Read the csv file named Ecommerce Customers.csv**

# %% [markdown]
# **Check the head, info and describe of the dataframe**

# %% [markdown]
# **Plot a jointplot with Avg Session Length and Yearly Amount Spent**

# %%
#Sample output. Don't run this cell.

# %% [markdown]
# **Plot a jointplot with Time on App and Yearly Amount Spent**

# %% [markdown]
# **Plot a jointplot (kind hex) with Time on Website and Yearly Amount Spent**

# %% [markdown]
# **Plot a pairplot of the entire dataframe**

# %% [markdown]
# **Plot a lmplot with Length of Membership and Yearly Amount Spent**

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# **Decide what columns to keep for X and which ones for y**

# %% [markdown]
# **Split the data using train_test_split**

# %% [markdown]
# **Import the LinearRegression class and create an object of it**

# %% [markdown]
# **Fit the training data into the algorithm**

# %% [markdown]
# **Check the co-efficients**

# %% [markdown]
# **Make predictions and print them**

# %% [markdown]
# ## Evaluation
#
# (I will explain this part on Monday)
